# %%
class Animal():
  def make_sound(self):
    print("Some animal sound")

# %%
class dog():
  def make_sound(self):
    print("Bark")

# %%
a = Animal()
a.make_sound()
# Out:
# Some animal sound

# %%
d = dog()
d.make_sound()
# Out:
# Bark
